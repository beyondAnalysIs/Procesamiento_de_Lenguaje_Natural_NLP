# %% [markdown]
# ### Modelos probabilísticos de Markov
# #### Propiedad fundamental de los Modelos de Markov
# - es como cuando solo consideras el clima de hoy para predecir el de mañana, ignorando como estuvo la semana pasada
# #### Estructura y Entrenamiento de un Modelo de Markov
# - Deficicion y componentes del modelo
# - Matriz de transición de estados
# - Entrenamiento del modelo
# #### Aplicaciones en el PLN
# - Clasificacion de texto (Spam)
# - Generación de texto original (poemas)
# - Diferencia entre aprendizaje supervisado y no supervisado
#     - apredizaje supervisado, entreno un modelo en base a una historia que se cuales seran los resultados, ej. clasificacion de noticias
#
# ### Resumen
# - son esencialmente sistemas que pasan de un estado a otro con ciertas probabilidades
# - estas probabilidades no dependen de como llego al estado actual, sino solo del estado actual en sí
#
# ### Representación matamática
# - si tenemos tres estados, A,B y C, la probabilidad de pasar de A a B podria ser representada por P(B|A)
# - A representa qu eesta soleado y B que esta nublado, P(B|A) es la probabilidad de que se ve vuelva nublado dado que ghoy esta soleado
#
# ### Uso de los modelos de Markov para secuencias
# - para predecur la siguiente palabra basandote en la actual
# - ej. después de la palabra 'buenos', la palabra 'dias' aparece un 80% de las veces, entonces: P('dias'|'buenos') = 0.8
#
# ### Estados en Modelos de Markov
# - Estados y simbolos categoricos
#     - ej, modelo de markov para prever el clima, los estados podrian ser: 'soleado', 'lluvioso', 'nublado'
#     - los estados los declaramos con S de (State)
#
# - Notación y representación
#     - usando la notación anterior, 'si' puede ser 'soleado'  y 'sj' 'lluvioso' la probabilidad de que despues de un dia soleado venga de un dia llo¡uvioso es P(sj|si)
#
# -Convensión de numeración de los estados:
#     - soleado = 1; lluviso = 2; nublado: 3
#
# - Distribución de probabilidad de los estados
#     - suma de las probabulidades de transición desde 'soleado' a todos los estados(incluyendo quedarse 'soleado') es 1
#
# ### Suavizado de Probabilidades
# #### estimaciones de maxima verosimilitud
# P(word2|word1) = count(word1, word2) / count(word1)
#
# - suavizados + 1
# - suavizado epsilon
#
# ### Probabilidad de una secuencia
# P(secuence) = P(word1) x P(word2|word1)x...x P(wordn|wordn-1)
# donde:
# - P(word1) es la probabilidad de que aparezca la primera palabra
# -  P(word2|word1) es la probabilidad de que la segunda palabra aparezca despues de la primera
# -  P(wordn|wordn-1) es la probabilidad de que la ultima palabra aparezca despues de la penultima palabra
